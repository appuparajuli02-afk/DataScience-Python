# %%
def check_palindrome(number):
   return str(number)==str(number)[::-1]

num=int(input("Enter a number:"))

if check_palindrome(num):
  print("Palindrome number")
else:
  print("NOt a palindrome number")
# Out:
# Enter a number:121
# Palindrome number

# %%
class car:
  def __init__(self,name,color):
    self.name=name
    self.color=color

  def start(self):
    return f"{self.name} is starting."

  def stop(self):
    return f"{self.name} has stopped."

ford=car(name="Ford",color="Black")
print(ford.name)
print(ford.color)
print(ford.start())
print(ford.stop())
# Out:
# Ford
# Black
# Ford is starting.
# Ford has stopped.
