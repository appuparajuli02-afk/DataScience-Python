# %%
import numpy as np
import pandas as pd 

data = {
    "name": ["Ram", "Sita", "Hari", "Gita", "John", "asma", "bibek", "sabal"],
    "age": [22, 25, 28, 21, 30, 20, 31, 23],
    "salary": [30000, 45000, 50000, 28000, 60000, 45000, 40000, 50000],
    "city": ['kathmandu', 'pokhara', 'kathmandu', 'dhangadi', 'chitwan', 'dhading', 'pokhara', 'jhapa']
}

data_df = pd.DataFrame(data)

# top row


data_df.head()
# Out:
#    name  age  salary       city
# 0   Ram   22   30000  kathmandu
# 1  Sita   25   45000    pokhara
# 2  Hari   28   50000  kathmandu
# 3  Gita   21   28000   dhangadi
# 4  John   30   60000    chitwan

# %%
data_df.tail()
# Out:
#     name  age  salary      city
# 3   Gita   21   28000  dhangadi
# 4   John   30   60000   chitwan
# 5   asma   20   45000   dhading
# 6  bibek   31   40000   pokhara
# 7  sabal   23   50000     jhapa

# %%
data_df.describe()
# Out:
#              age        salary
# count   8.000000      8.000000
# mean   25.000000  43500.000000
# std     4.208834  10663.690061
# min    20.000000  28000.000000
# 25%    21.750000  37500.000000
# 50%    24.000000  45000.000000
# 75%    28.500000  50000.000000
# max    31.000000  60000.000000

# %%
print(data_df["age"]).mean()

#print(data_df["salary"]).mean()
# Out:
# 0    22
# 1    25
# 2    28
# 3    21
# 4    30
# 5    20
# 6    31
# 7    23
# Name: age, dtype: int64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(data_df["age"]).mean()
#       2
#       3 #print(data_df["salary"]).mean()
#
# AttributeError: 'NoneType' object has no attribute 'mean'

# %%
age_data=data_df["age"]
age_data
# Out:
# 0    22
# 1    25
# 2    28
# 3    21
# 4    30
# 5    20
# 6    31
# 7    23
# Name: age, dtype: int64

# %%
type(age_data)
# Out:
# pandas.Series

# %%
new_df=data_df[["name","age","salary"]]
print(new_df)
# Out:
#     name  age  salary
# 0    Ram   22   30000
# 1   Sita   25   45000
# 2   Hari   28   50000
# 3   Gita   21   28000
# 4   John   30   60000
# 5   asma   20   45000
# 6  bibek   31   40000
# 7  sabal   23   50000

# %%
#selecting rows
#using iloc-> integer location
data_df.iloc[0]
# Out:
# name            Ram
# age              22
# salary        30000
# city      kathmandu
# Name: 0, dtype: object

# %%
#first three rows
data_df.iloc[0:3]
# Out:
#    name  age  salary       city
# 0   Ram   22   30000  kathmandu
# 1  Sita   25   45000    pokhara
# 2  Hari   28   50000  kathmandu

# %%
#specific rows and columns
data_df.iloc[0,1]
# Out:
# np.int64(22)

# %%
data_df.iloc[0]
# Out:
# name            Ram
# age              22
# salary        30000
# city      kathmandu
# Name: 0, dtype: object

# %%
data_df.loc[0,["name","age"]]
# Out:
# name    Ram
# age      22
# Name: 0, dtype: object

# %%
#Multiple rows
data_df.loc[0:2,["name","salary"]]
# Out:
#    name  salary
# 0   Ram   30000
# 1  Sita   45000
# 2  Hari   50000

# %%
#iloc lae index use garxa and loc lae value ko name

# %% [markdown]
# Filtering Data

# %%
#age greater than condition

data_df[data_df["age"]>25]
# Out:
#     name  age  salary       city
# 2   Hari   28   50000  kathmandu
# 4   John   30   60000    chitwan
# 6  bibek   31   40000    pokhara

# %%
#age greater than 22 and salary greater than 40,000
data_df[(data_df["age"] > 22) & (data_df["salary"] > 40000)]
# Out:
#     name  age  salary       city
# 1   Sita   25   45000    pokhara
# 2   Hari   28   50000  kathmandu
# 4   John   30   60000    chitwan
# 7  sabal   23   50000      jhapa

# %% [markdown]
# Reading CSV file

# %%
#filepath="D:\MovedFolder\DataSciencePythonevening\DataScienceCourse\numpy\dataset\index_1.csv"
filepath=filepath = r"D:\MovedFolder\DataSciencePythonevening\DataScienceCourse\numpy\dataset\index_1.csv"
sales_df=pd.read_csv(filepath)
sales_df.head()
# Out:
#          date                 datetime cash_type                 card  money  \
# 0  2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001   38.7
# 1  2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002   38.7
# 2  2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002   38.7
# 3  2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003   28.9
# 4  2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004   38.7
#
#      coffee_name
# 0          Latte
# 1  Hot Chocolate
# 2  Hot Chocolate
# 3      Americano
# 4          Latte

# %%
sales_df.describe()
# Out:
#              money
# count  3636.000000
# mean     31.746859
# std       4.919926
# min      18.120000
# 25%      27.920000
# 50%      32.820000
# 75%      35.760000
# max      40.000000

# %%
sales_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3636 entries, 0 to 3635
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3636 non-null   str
#  1   datetime     3636 non-null   str
#  2   cash_type    3636 non-null   str
#  3   card         3547 non-null   str
#  4   money        3636 non-null   float64
#  5   coffee_name  3636 non-null   str
# dtypes: float64(1), str(5)
# memory usage: 170.6 KB

# %%
sales_df.isnull()
# Out:
#        date  datetime  cash_type   card  money  coffee_name
# 0     False     False      False  False  False        False
# 1     False     False      False  False  False        False
# 2     False     False      False  False  False        False
# 3     False     False      False  False  False        False
# 4     False     False      False  False  False        False
# ...     ...       ...        ...    ...    ...          ...
# 3631  False     False      False  False  False        False
# 3632  False     False      False  False  False        False
# 3633  False     False      False  False  False        False
# 3634  False     False      False  False  False        False
# 3635  False     False      False  False  False        False
#
# [3636 rows x 6 columns]

# %%
# import pandas as pd

# data = {    "name": [        "Ram", "Sita", "Hari",        "Gita", "John", "Rita"    ],    "age": [20, 24, 22, 27, 30, 25],    "city": [        "Kathmandu", "Pokhara", "Kathmandu",        "Chitwan", "Pokhara", "Kathmandu"    ],    "marks": [75, 88, 65, 92, 55, 81]}

# df = pd.DataFrame(data)

# %% [markdown]
# Display the complete DataFrame.
# Display the first 3 rows.
# Find the number of rows and columns.
# Display all column names.
# Select only the name column.
# Select name and marks.
# Find the average marks.
# Find the highest and lowest marks.
# Find students older than 23.
# Find students with marks greater than 80.
# Find students from Kathmandu.
# Find students from Kathmandu whose marks are greater than 75.
# Display the first student's data using iloc.
# Select rows 1–3 using iloc.
# Use describe() to inspect numerical columns.

# %%
import pandas as pd

data = { "name": [ "Ram", "Sita", "Hari",        "Gita", "John", "Rita"    ],    "age": [20, 24, 22, 27, 30, 25],    "city": [        "Kathmandu", "Pokhara", "Kathmandu",        "Chitwan", "Pokhara", "Kathmandu"    ],    "marks": [75, 88, 65, 92, 55, 81]}

df = pd.DataFrame(data)

# %%
print(df)
# Out:
#    name  age       city  marks
# 0   Ram   20  Kathmandu     75
# 1  Sita   24    Pokhara     88
# 2  Hari   22  Kathmandu     65
# 3  Gita   27    Chitwan     92
# 4  John   30    Pokhara     55
# 5  Rita   25  Kathmandu     81

# %%
df.head(3)
# Out:
#    name  age       city  marks
# 0   Ram   20  Kathmandu     75
# 1  Sita   24    Pokhara     88
# 2  Hari   22  Kathmandu     65

# %%
df.shape
# Out:
# (6, 4)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city', 'marks'], dtype='str')

# %%
df["name"]
# Out:
# 0     Ram
# 1    Sita
# 2    Hari
# 3    Gita
# 4    John
# 5    Rita
# Name: name, dtype: str

# %%
df.loc[:,["name","marks"]]

#df.loc[:, ["name", "marks"]]
# Out:
#    name  marks
# 0   Ram     75
# 1  Sita     88
# 2  Hari     65
# 3  Gita     92
# 4  John     55
# 5  Rita     81

# %%
print("The average marks is:",df["marks"].mean())
# Out:
# The average marks is: 76.0

# %%
# Out:
# np.int64(92)

# %%
# Out:
# np.int64(55)

# %%
print("The highest marks is:", df["marks"].max())
# Out:
# The highest marks is: 92

# %%
print("The lowest marks is:",df["marks"].min())
# Out:
# The lowest marks is: 55

# %%
df[df["age"]>23]
# Out:
#    name  age       city  marks
# 1  Sita   24    Pokhara     88
# 3  Gita   27    Chitwan     92
# 4  John   30    Pokhara     55
# 5  Rita   25  Kathmandu     81

# %%
df[df["marks"]>80]
# Out:
#    name  age       city  marks
# 1  Sita   24    Pokhara     88
# 3  Gita   27    Chitwan     92
# 5  Rita   25  Kathmandu     81

# %%
df[df["city"]=="Kathmandu"]
# Out:
#    name  age       city  marks
# 0   Ram   20  Kathmandu     75
# 2  Hari   22  Kathmandu     65
# 5  Rita   25  Kathmandu     81

# %%
df[(df["city"] == "Kathmandu") & (df["marks"] > 75)]
# Out:
#    name  age       city  marks
# 5  Rita   25  Kathmandu     81

# %% [markdown]
# Display the first student's data using iloc.
# Select rows 1–3 using iloc.
# Use describe() to inspect numerical columns.

# %%
df.iloc[0]
# Out:
# name           Ram
# age             20
# city     Kathmandu
# marks           75
# Name: 0, dtype: object

# %%
df.iloc[1:4]
# Out:
#    name  age       city  marks
# 1  Sita   24    Pokhara     88
# 2  Hari   22  Kathmandu     65
# 3  Gita   27    Chitwan     92

# %%
df.describe()
# Out:
#              age      marks
# count   6.000000   6.000000
# mean   24.666667  76.000000
# std     3.559026  14.057027
# min    20.000000  55.000000
# 25%    22.500000  67.500000
# 50%    24.500000  78.000000
# 75%    26.500000  86.250000
# max    30.000000  92.000000

# %%
df
# Out:
#    name  age       city  marks
# 0   Ram   20  Kathmandu     75
# 1  Sita   24    Pokhara     88
# 2  Hari   22  Kathmandu     65
# 3  Gita   27    Chitwan     92
# 4  John   30    Pokhara     55
# 5  Rita   25  Kathmandu     81
