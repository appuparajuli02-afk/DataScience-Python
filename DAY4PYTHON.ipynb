# %% [markdown]
# #DAY 4 PYTHON
# ##Functions

# %%
def greet():
  print("Hello welcome to the class")
greet()
greet()
# Out:
# Hello welcome to the class
# Hello welcome to the class

# %%
def greet_student(name):
  print(f"Hello {name} welcome to the class.")
greet_student("Ashma")
# Out:
# Hello Ashma welcome to the class.

# %%
def introduce(name,address):
  print(f"My name is {name} and I live in {address}.")
introduce("Ram","Chitwan")
introduce(name="Hari",address="KTM")
introduce(address="PKR",name="Tony")
# Out:
# My name is Ram and I live in Chitwan.
# My name is Hari and I live in KTM.
# My name is Tony and I live in PKR.

# %%
#Returning a value
def add_number(num1,num2):
  return num1+num2
add_number(5,7)
# Out:
# 12

# %%
def add_number(num1,num2):
  result=num1+num2
  return result

total=add_number(10,20)
final_result= total ** 2
print(total)
print(final_result)
#print displays the value but return sends the value back so it
# can be stored, reused or processed
# Out:
# 30
# 900

# %%
#Default Parameters
def calculator(num1,num2):
  addition=(num1+num2)
  multiplication=num1*num2
  return addition,multiplication

result,result1=calculator(10,20)
print(result)
print(result1)
# Out:
# 30
# 200

# %%
#Global Variable
message="This is global variable"
def show_message():
  print(message)
show_message
print(message)
# Out:
# This is global variable

# %%
#Check odd or even number
def check_number(num):
  if num %2==0:
    print("Even number")
  else:
    print("Odd number")
check_number(5)
check_number(10)
# Out:
# Odd number
# Even number

# %%
#Reverse word
def reverse_word(text:str)->str:
  word=text[::-1]
  print(word)
reverse_word("Programming")
# Out:
# gnimmargorP

# %%
#Return the largest number
def largest_number(num1,num2):
  if num1>num2:
    return num1
  else:
    return num2
largest_number(50,90)
# Out:
# 90

# %%
def larg_num(numbers):
  return max(numbers)
numbers=[5,7,9,8,45,68]
larg_num(numbers)
# Out:
# 68

# %%
def max_number(numbers):
  largest=numbers[0]

  for num in numbers:
    if num>largest:
      largest=num
  return largest
numbers=[10,20,30,4,8,9,39]
print("The largest number is", max_number(numbers))
# Out:
# The largest number is 39

# %% [markdown]
# 1.atm tracker(deposit, withdraw, balance check, exit) using functions
# validate pin (4 digit)
# check withdraw or deposit amount is in negative or not
# display error message
#
# 2.simple calculator
# ask user for two numbers and operators
# handle invalid numeric input (handle division by zero)
# display an error for an invalid operation
#
# 3.student grade calculator using functions
#
# 4.functions to check voting eligiblilty

# %% [markdown]
# ATM TRACKER

# %%
accounts=[
    {
        'Accno':123456789,
        'Name': 'Tony Stark',
        'Pin': 9876,
        'balance':15000
    },
    {
            'Accno':987654321,
            'Name': 'Steve Rogers',
            'Pin': 1234,
            'balance':10000
        },
    {
                'Accno':984524310,
                'Name': 'Sam Wilson',
                'Pin': 5678,
                'balance':20000
     },
     {
             'Accno':984506677,
             'Name': 'Peter Parker',
             'Pin': 9012,
             'balance':5000
         },
    {
            'Accno':751111223,
            'Name': 'Wanda',
            'Pin': 8520,
            'balance':25000
        }
]

def welcome():
    print('*'*30)
    print("Welcome to XYZ Bank")
    print('*'*30)

def verify_pin():
    acc=int(input("Enter Account Number:"))
    entered_pin=int(input("Enter your pin"))
    for account in accounts:
        if account['Accno']==acc and account['Pin']== entered_pin:
          print("Login Successfully")
          return account

    print("Incorrect account number or Pin")
    return None

def show_menu():
    print("\n-------Bank Management System Menu---------")
    print("1.Create new account")
    print("2.View All Account")
    print("3. Search Account")
    print("4.Deposit Money")
    print("5.Withdraw Money")
    print("6.Change PIN")
    print("7.Delete Account")
    print("8.Exit")

def create_account():
    accno=input("Enter your account numbber:")
    name=input("Enter your name:")
    pin=int(input("Enter your name:"))
    balance=float(input("Enter your balance:"))

    account={
        "Accno": accno,
        "Name":name,
        "Pin":pin,
        "balance":balance
         }
    accounts.append(account)
    print("\n New Account Created Successfully")

def view_account():
    if len(accounts)==0:
        print("No account found")
        return
    print("------Accounts Details-------")

    for account in accounts:
        print(f"AccNo: {account['Accno']}")
        print(f"Name: {account['Name']}")
        print(f"Pin: {account['Pin']}")
        print(f"Balance: {account['balance']}")
        print('*'*30)

def search_accounts():
    acc=int(input("Enter your account number:"))
    found=False
    for account in accounts:
        if account['Accno']==acc:
            print("Account found")
            print("*"*30)
            print(f"Accno:{account['Accno']}")
            print(f"Name:{account['Name']}")
            print(f"Balance:{account['balance']}")
            found=True
            break;

    if not found:
            print("Account not found")

def deposit(account):
  while True:
    try:
        amount=float(input("Enter the money you want to deposit:"))
        if amount<=0:
              print("Invalid Amount! Please enter a positive number.")
        else:
             account['balance']+=amount
             print("Deposit Successfull")
             print("New Balance:",account['balance'])
             break
    except ValueError:
          print("Please enter a valid number.")

def withdraw(account):
  try:
    amount=float(input("Enter the money you want to withdraw:"))
    if amount<=0:
        print("Invalid Amount")

    elif amount> account['balance']:
        print("Insufficient balance")
    else:
        account['balance']=account['balance']-amount
        print("Withdraw successfull")
        print("New Balance:",account['balance'])
  except ValueError:
        print("Invalid Amount")

def change_pin(account):
    old_pin=int(input("Enter your old pin:"))
    if old_pin==account['Pin']:
        new_pin=int(input("Enter your new pin:"))
        account['Pin']=new_pin
        print("Pin changed successfully")
    else:
        print("Incorrect Pin")

def delete_account(account):
    # acc=int(input("Enter your account number:"))
    # for account in accounts:
    #     if account['Accno']==acc:
    #         accounts.remove(account)
    #         print("Account deleted successfully")
    #         return;
    # print("Account not found")
    accounts.remove(account)
    print("Account deleted successfully")

def menu():
    current_account =verify_pin()
    if current_account is None:
        return
    while True:
        show_menu()
        choice=input("Enter your choice:")

        if choice=='1':
            create_account()

        elif choice=='2':
            view_account()

        elif choice=='3':
            search_accounts()

        elif choice=='4':
            deposit(current_account)

        elif choice=='5':
            withdraw(current_account)

        elif choice=='6':
            change_pin(current_account)

        elif choice=='7':
            delete_account(current_account)

        elif choice=='8':
            print("Thank you for choosing our XYZ Bank")
            break
        else:
            print("Invalid Choice")

welcome()
menu()
# Out:
# ******************************
# Welcome to XYZ Bank
# ******************************
# Enter Account Number:123456789
# Enter your pin9876
# Login Successfully
#
# -------Bank Management System Menu---------
# 1.Create new account
# 2.View All Account
# 3. Search Account
# 4.Deposit Money
# 5.Withdraw Money
# 6.Change PIN
# 7.Delete Account
# 8.Exit
# Enter your choice:5
# Enter the money you want to withdraw:-1000
# Invalid Amount
#
# -------Bank Management System Menu---------
# 1.Create new account
# 2.View All Account
# 3. Search Account
# 4.Deposit Money
# 5.Withdraw Money
# 6.Change PIN
# 7.Delete Account
# 8.Exit
# Enter your choice:8
# Thank you for choosing our XYZ Bank

# %% [markdown]
# Calculator

# %%
# num1=float(input("Enter your first number:"))
# num2=float(input("Enter your second number:"))

# def show_menu():
#   print("---------Calculator--------")
#   print("1.Addition")
#   print("2.Subtraction")
#   print("3.Multiplication")
#   print("4.Division")
#   print("5.Exit")

# def add_num(num1,num2):
#   return num1+num2

# def sub_num(num1,num2):
#   return num1-num2

# def mul_num(num1,num2):
#   return num1*num2

# # def div_num(num1,num2):
# #    if num2==0:
# #     print("Cannot divide by zero.")
# #    return num1/num2
# def div_num(num1, num2):
#     if num2 == 0:
#         return "Cannot divide by zero."
#     return num1 / num2

# def calculator():
#   while True:
#     show_menu()
#     choice=int(input("Enter your choice from 1-5:"))

#     if choice==1:
#       print("Result:,add_num(num1,num2)")
#     elif choice==2:
#       print("Result:,sub_num(num1,num2)")

#     elif choice==3:
#       print("Result:,mul_num(num1,num2)")

#     elif choice==4:
#       print("Result:,div_num(num1,num2)")

#     elif choice==5:
#       print("Thank you for using calculator")
#       break
#     else:
#       print("Invalid choice")

# calculator()
# Out:
# Enter your first number:10
# Enter your second number:5
# ---------Calculator--------
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# 5.Exit
# Enter your choice from 1-5:4
# Result:,div_num(num1,num2)
# ---------Calculator--------
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# 5.Exit
# Enter your choice from 1-5:5
# Thank you for using calculator

# %%
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b == 0:
        return "Cannot divide by zero."
    return a / b


def calculator():
    while True:
        print("\n===== SIMPLE CALCULATOR =====")
        print("1. Addition")
        print("2. Subtraction")
        print("3. Multiplication")
        print("4. Division")
        print("5. Exit")

        choice = input("Enter your choice (1-5): ")

        if choice == "5":
            print("Thank you for using the calculator!")
            break

        if choice not in ["1", "2", "3", "4"]:
            print("Invalid choice! Please try again.")
            continue

        try:
            num1 = float(input("Enter first number: "))
            num2 = float(input("Enter second number: "))

            if choice == "1":
                print("Result:", add(num1, num2))

            elif choice == "2":
                print("Result:", subtract(num1, num2))

            elif choice == "3":
                print("Result:", multiply(num1, num2))

            elif choice == "4":
                print("Result:", divide(num1, num2))

        except ValueError:
            print("Please enter valid numbers.")


calculator()
# Out:
# ===== SIMPLE CALCULATOR =====
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice (1-5): 4
# Enter first number: 10
# Enter second number: 5
# Result: 2.0
#
# ===== SIMPLE CALCULATOR =====
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice (1-5): 5
# Thank you for using the calculator!

# %% [markdown]
# Student Grade Calculator

# %%
def calculate_grade(marks):
  if marks>=90:
    return "A+"
  elif marks>=80:
    return "A"
  elif marks>=70:
    return "B+"
  elif marks>=60:
    return "B"
  elif marks>=50:
    return "C"
  elif marks>=40:
    return "D"
  else:
    return "E"

def student():
  try:
   name=input("Enter the name of student:")
   marks=float(input("Enter the marks of the student:"))

   if marks<0 or marks>100:
     print("Marks should be between 0 and 100")
     return

   grade=calculate_grade(marks)
   print("----Result-----")
   print("Name:",name)
   print("Marks:",marks)
   print("Grade:",grade)

  except ValueError:
   print("Please enter a valid number.")

student()
# Out:
# Enter the name of student:Ashma Parajuli
# Enter the marks of the student:66
# ----Result-----
# Name: Ashma Parajuli
# Marks: 66.0
# Grade: B

# %% [markdown]
# Voting Eligibility

# %%
def check_eligibility(age):
  if age>=18:
    return "You are eligible to vote."
  elif age>=0:
    return "You are not eligible to vote."
  else :
    return "Age cannot be in negative."

def voting():
  try:
    name=input("Enter you name:")
    age=int(input("Enter your age:"))

    result=check_eligibility(age)
    print("-----Result-----")
    print("Name:",name)
    print("Age:",age)
    print("Result:",result)

  except ValueError:
    print("Enter a valid age.")

voting()
# Out:
# Enter you name:Ashma Parajuli
# Enter your age:15
# -----Result-----
# Name: Ashma Parajuli
# Age: 15
# Result: You are not eligible to vote.

# %% [markdown]
# ATM USING CLASS

# %%
class Account:
    def __init__(self,accno,pin,name,balance):
        self.accno=accno
        self.pin=pin
        self.name=name
        self.balance=balance

    # try:
    #     pinno=int(input("Enter your pin:"))
    #     if pinno==self.pin:
    #         print("Welcome to the ATM.")

    #     else:
    #         print("Your pin is incorrect.")

    # except ValueError:
    #     print("Please enter the valid number only.")


    def deposit(self):
        try:
         amount=int(input("Enter the amount you want to deposit:"))
         self.balance+=amount
         print("Your new amount is:",self.balance)

        except ValueError:
            print("Please enter the valid number only.")

    def withdraw(self):
        try:
            with_amount=int(input("Enter the amount you want to withdraw:"))
            if with_amount>self.balance:
                print("Not sufficient money.")

            else:
                self.balance-=with_amount
                print("Your current balance is:",self.balance)

        except ValueError:
            print("Enter the valid number.")


    def check_balance(self):
        return f"Your current balance is:{self.balance}"


    def change_pin(self):
        try:
         curr_pin=int(input("Enter your current pin:"))
         if curr_pin==self.pin:
             new_pin=int(input("Enter your new pin:"))
             self.pin=new_pin
             print("Pin changed successfully.")

         else:
             print("Incorrect current PIN")

        except ValueError:
            print("Enter the valid number only.")


class ATM:
    def __init__(self,account):
        self.account=account

    def login(self):
        pinno=int(input("Enter your pin:"))
        if pinno==self.account.pin:
            print("Welcome to the ATM")
            return True
        
        else:
            print("Wrong pin number.")
            return False

    def show_menu(self):
        print("Welcome to the ATM Menu")
        print("1.Deposit Money")
        print("2.Withdraw Money")
        print("3.Check balance")
        print("4.Change PIN")
        print("5.Exit")

    def deposit_money(self):
        #amt=int(input("Enter the money you want to deposit:"))
        self.account.deposit()

    def withdraw_money(self):
        #amount=int(input("Enter the money you want to withdraw:"))
        self.account.withdraw()

    def check_balance(self):
        print(self.account.check_balance())

    def change_pin(self):
        #pin=int(input("Enter your new pin:"))
        self.account.change_pin()

    def run(self):
        if not self.login():
            return
        while True:
            self.show_menu()
            try:
                choice=int(input("Enter your choice (1-5): "))

                if choice==1:
                   self.deposit_money()
                elif choice==2:
                    self.withdraw_money()
                elif choice==3:
                    self.check_balance()
                elif choice==4:
                    self.change_pin()
                elif choice==5:
                     print("Thank you for using our ATM.")
                     break
                else:
                 return "Please enter a valid choice."
                
            except ValueError:
                print("Please enter numbers only.")



acc1=Account(123456789,1234,"Tony Stark",500000)
atm=ATM(acc1)
atm.run()
# Out:
# Welcome to the ATM
# Welcome to the ATM Menu
# 1.Deposit Money
# 2.Withdraw Money
# 3.Check balance
# 4.Change PIN
# 5.Exit
# Thank you for using our ATM.
