# %% [markdown]
# String

# %%
text="      hello. "
print(text.strip())
print(text.lstrip())
print(text.rstrip())
# Out:
# hello.
# hello.
#       hello.

# %%
text="apple,banana,mango"
text.split(",")
# Out:
# ['apple', 'banana', 'mango']

# %%
items=['apple','banana']
print("-".join(items))
# Out:
# apple-banana

# %%
text="I love to go hiking."
text.find("love")
# Out:
# 2

# %%
text="banana"
text.count("a")
# Out:
# 3

# %% [markdown]
# Tuple

# %%
person=('ram',12,True)
person[0]
# Out:
# 'ram'

# %% [markdown]
# Set

# %%
numbers={1,2,3}
numbers
# Out:
# {1, 2, 3}

# %%
numbers.add(4)
numbers
# Out:
# {1, 2, 3, 4}

# %%
a={'apple','banana','orange'}
b={'orange','microsoft','google'}
a.union(b)
# Out:
# {'apple', 'banana', 'google', 'microsoft', 'orange'}

# %%
a.intersection(b)
# Out:
# {'orange'}

# %%
a.difference(b)
# Out:
# {'apple', 'banana'}

# %%
b.difference(a)
# Out:
# {'google', 'microsoft'}

# %%
a-b
# Out:
# {'apple', 'banana'}

# %% [markdown]
# Dictionary

# %%
person={
    "name":"Hari",
    "age":20,
    'course':'python'
}
person
# Out:
# {'name': 'Hari', 'age': 20, 'course': 'python'}

# %%
person["name"]
# Out:
# 'Hari'

# %%
person.get("address","KTM")
# Out:
# 'KTM'

# %%
person['age']=25
person
# Out:
# {'name': 'Hari', 'age': 25}

# %%
del person['course']
person
# Out:
# {'name': 'Hari', 'age': 20}

# %%
person.values()
# Out:
# dict_values(['Hari', 20])

# %%
person.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
#loop
for key,value in person.items():
  print(f"{key}->,{value}")
# Out:
# name->,Hari
# age->,20

# %% [markdown]
# #Exercise
# Reverse every word in the sentence("I love to travel a lot")

# %%
sentence=("I love to travel a lot")
new=sentence.split()
print(new)
new_list=new[::-1]
print(" ".join(new_list))
# Out:
# ['I', 'love', 'to', 'travel', 'a', 'lot']
# lot a travel to love I

# %%
sentence=("I love to travel a lot")
print(sentence[::-1])
# Out:
# tol a levart ot evol I

# %%
word=input("Enter a word:")
wprd=word.lower()
if word==word[::-1]:
  print("Palindrom word")
else:
  print("Not a palindrom word")
# Out:
# Enter a word:madam
# Palindrom word

# %% [markdown]
# 1.Reverse a string
# 2.Count words
# 3.Find largest number in list
# 4.Count vowels
# 5.Remove duplicates from the list.

# %%
string="Hello"
print(string[::-1])
# Out:
# olleH

# %%
sentence="I love Nepal"
new=sentence.split()
print(new)
new_word=new[::-1]
print(" ".join(new_word))
# Out:
# ['I', 'love', 'Nepal']
# Nepal love I

# %%
string="Hello World"
print(string.count('o'))
# Out:
# 2

# %%
numbers=[10,50,90,5,100,18]
print(max(numbers))
# Out:
# 100

# %%
numbers=[10,20,65,98,7]
numbers.sort()
print(numbers)
print(numbers[-1])
# Out:
# [7, 10, 20, 65, 98]
# 98

# %%
string=input("Enter the sentence:")
words=string.split()

for word in words:
  for char in word:
    if char.lower() in "aeiou":
      print(word)
      break
# Out:
# Enter the sentence:hello word
# hello
# word

# %%
numbers = [1, 2, 2, 3, 4, 4, 5]

numbers = list(set(numbers))

print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
word="Python"
reversed_word=""
for char in word:
  reversed_word=char+reversed_word
  #print(reversed_word)
print(reversed_word)
# Out:
# nohtyP

# %%
sentence="Nepal is a beautiful country."
words=sentence.split()
print(words.count('Nepal'))
# Out:
# 1
